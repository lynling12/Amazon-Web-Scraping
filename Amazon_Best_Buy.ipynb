# %%
import json
from pprint import pprint

with open('data.json') as data_file:    
    data = json.load(data_file)
pprint(data)
# Out:
# [{u'AVAILABILITY': u'In Stock.',
#   u'BRAND_NAME': u'Ergotron',
#   u'CATEGORY': u'Office Products > Office & School Supplies > Desk Accessories & Workspace Organizers > Platforms, Stands & Shelves',
#   u'NAME': u'Ergotron WorkFit-TL, Sit-Stand Desk Converter | Black, 37.5" wide | For Tabletops',
#   u'ORIGINAL_PRICE': u'$415.00',
#   u'SALE_PRICE': u'$415.00',
#   u'URL': u'http://www.amazon.com/dp/B015H5MDIO'},
#  {u'AVAILABILITY': u'',
#   u'BRAND_NAME': u'Versa Tables',
#   u'CATEGORY': u'Office Products > Office Furniture & Lighting > Desks & Workstations > Computer Workstations',
#   u'NAME': u'VersaDesk Power Pro - 36" Electric Height Adjustable Standing Desk Riser. Power Sit to Stand Desktop Converter with Keyboard Tray. Black.',
#   u'ORIGINAL_PRICE': u'$390.00',
#   u'SALE_PRICE': u'$390.00',
#   u'URL': u'http://www.amazon.com/dp/B01H0S58M4'},
# ...

# %%
import pandas as pd
data = pd.DataFrame(data)
data
# Out:
#                                          AVAILABILITY           BRAND_NAME  \
# 0                                           In Stock.             Ergotron
# 1                                                             Versa Tables
# 2   Currently unavailable.\n        \n        \n  ...                 Pyle
# 3                                           In Stock.        Basic Support
# 4                                           In Stock.                iMovR
# 5                                           In Stock.               SMONET
# 6                                           In Stock.            FLEXISPOT
# 7                                           In Stock.            FLEXISPOT
# 8                                           In Stock.            Mount-It!
# 9                                           In Stock.               FEZIBO
# 10                                          In Stock.  Stand Up Desk Store
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 7 columns):
# AVAILABILITY      61 non-null object
# BRAND_NAME        61 non-null object
# CATEGORY          61 non-null object
# NAME              62 non-null object
# ORIGINAL_PRICE    59 non-null object
# SALE_PRICE        59 non-null object
# URL               62 non-null object
# dtypes: object(7)
# memory usage: 3.5+ KB

# %%
Brand = data.groupby('BRAND_NAME').size()
Brand
# Out:
# BRAND_NAME
# 1home                  1
# Basic Support          1
# Bestyle                1
# Casiii                 2
# Defy Desk              1
# DeskDoc                1
# Ergotron               1
# FEZIBO                 4
# FLEXISPOT              6
# Fancierstudio          1
# G-Technology           1
# Green Forest           1
# Halter                 1
# High Supply            1
# LANGRIA                1
# Mount-It!              6
# Pyle                   1
# SITA-OFFICE            2
# SMONET                 1
# Slendor                1
# Smugdesk               1
# Stand Steady           2
# Stand Up Desk Store    4
# The House of Trade     1
# UPDEZK                 1
# VARIDESK               5
# VIVO                   9
# Versa Tables           2
# iMovR                  1
# dtype: int64

# %%
# import samplemissing.csv
import csv
ti=pd.read_csv("data/BSAleS.csv")
ti
# Out:
#              BRAND_NAME SALES $
# 0              Ergotron     415
# 1          Versa Tables     390
# 2                  Pyle    None
# 3         Basic Support     149
# 4                 iMovR     349
# 5                SMONET  189.99
# 6             FLEXISPOT  299.99
# 7             FLEXISPOT  349.99
# 8             Mount-It!  204.99
# 9                FEZIBO  195.68
# 10  Stand Up Desk Store      89
# 11                 VIVO  229.99
# 12          SITA-OFFICE  189.99
# 13               Casiii     198
# 14             VARIDESK     495
# 15         Stand Steady  197.43
# 16  Stand Up Desk Store     169
# 17            Mount-It!  225.99
# 18             VARIDESK     395
# 19               FEZIBO  168.98
# 20               UPDEZK  159.95
# 21   The House of Trade  189.99
# 22                 VIVO  179.99
# 23             VARIDESK     395
# 24                 VIVO  179.99
# 25                 VIVO  229.99
# 26               Halter  199.99
# 27             VARIDESK     495
# ...

# %%
ti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
# BRAND_NAME    60 non-null object
# SALES $       60 non-null object
# dtypes: object(2)
# memory usage: 1.0+ KB
